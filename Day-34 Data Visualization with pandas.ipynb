# %% [markdown]
# ### Day 34 of python programming

# %% [markdown]
# ## Data Visualization with Pandas
# ### Introduction:
# Pandas integrates well with visualization libraries like Matplotlib and Seaborn to easily create plots.
#
# ### Step 1: Plotting Data with Pandas
# You can create plots directly using pandas’ built-in plotting features.

# %%
import pandas as pd

# Reading a CSV file
df = pd.read_csv('samplefile.csv', delimiter= ';')

# Displaying the first few rows
print(df.head())
df
# Out:
#     Name   Age Sex       City Occupation  Salary($)
# 0   John  32.0   M      Lagos     Doctor     2000.0
# 1   Mary  27.0   F  Frankfurt      Nurse     1500.0
# 2  Felix  42.0   M       Bonn     Lawyer     2800.0
# 3   Marc  45.0   M     Jersey     Lawyer     4000.0
# 4   Anna  32.0   F       Abia    Teacher     1200.0
#       Name   Age Sex       City Occupation  Salary($)
# 0     John  32.0   M      Lagos     Doctor     2000.0
# 1     Mary  27.0   F  Frankfurt      Nurse     1500.0
# 2    Felix  42.0   M       Bonn     Lawyer     2800.0
# 3     Marc  45.0   M     Jersey     Lawyer     4000.0
# 4     Anna  32.0   F       Abia    Teacher     1200.0
# 5     Linc   NaN   M    Cologne      Pilot     4000.0
# 6    Sarah  35.0   F        NaN    Manager     3500.0
# 7    Derek  49.0   M      Paris        NaN     2000.0
# 8     Mark  50.0   M     Russia     Banker     3400.0
# 9   Kelvin  34.0   M   New York    Plumber     1500.0
# 10     Tim  23.0   M        NaN     Dancer     2000.0
# ...

# %%
import matplotlib.pyplot as plt

# Plotting a histogram of a column
df['Age'].plot(kind='hist')
plt.show()

# %% [markdown]
# ### Visualizing all data

# %%
df.plot()

plt.show()

# %% [markdown]
# ### Step 2: Customizing Plots
# You can customize plots using parameters in pandas or through Matplotlib.

# %%
# Customizing a plot
df['Salary($)'].plot(kind='line', color='red', title='Salary over Time')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(kind = 'scatter', x = 'Age', y = 'Salary($)')

plt.show()

# %% [markdown]
# ### Step 3: Advanced Visualizations
# For more complex visualizations, you can use Seaborn.

# %%
import seaborn as sns

# Creating a boxplot
sns.boxplot(x='Sex', y='Salary($)', data=df)
plt.show()

# %% [markdown]
# ### Practice Questions:
# Create a bar plot of categorical data in a DataFrame.
#
# Plot a line graph for a time series column.
#
# Create a scatter plot to show the relationship between two numerical columns.
